# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
# reading csv
vaccination_file = "Resources/states.csv"
election_file = "Resources/Popular-vote-backend-Sheet1.csv"
vaccination_df = pd.read_csv(vaccination_file)

# %%
election_df = pd.read_csv(election_file)

# %%
vaccination_df
# Out:
#     fips country state  county  level  lat          locationId  long  \
# 0      2      US    AK     NaN  state  NaN  iso1:us#iso2:us-ak   NaN
# 1      1      US    AL     NaN  state  NaN  iso1:us#iso2:us-al   NaN
# 2      5      US    AR     NaN  state  NaN  iso1:us#iso2:us-ar   NaN
# 3      4      US    AZ     NaN  state  NaN  iso1:us#iso2:us-az   NaN
# 4      6      US    CA     NaN  state  NaN  iso1:us#iso2:us-ca   NaN
# 5      8      US    CO     NaN  state  NaN  iso1:us#iso2:us-co   NaN
# 6      9      US    CT     NaN  state  NaN  iso1:us#iso2:us-ct   NaN
# 7     11      US    DC     NaN  state  NaN  iso1:us#iso2:us-dc   NaN
# 8     10      US    DE     NaN  state  NaN  iso1:us#iso2:us-de   NaN
# 9     12      US    FL     NaN  state  NaN  iso1:us#iso2:us-fl   NaN
# 10    13      US    GA     NaN  state  NaN  iso1:us#iso2:us-ga   NaN
# 11    15      US    HI     NaN  state  NaN  iso1:us#iso2:us-hi   NaN
# 12    19      US    IA     NaN  state  NaN  iso1:us#iso2:us-ia   NaN
# ...

# %%
election_df
# Out:
#                    state called final   dem_votes   rep_votes other_votes  \
# 0             U.S. Total      D   Yes  81,282,916  74,223,369   2,891,441
# 1   15 Key Battlegrounds    NaN   NaN  31,908,248  33,002,287     950,354
# 2      Non-Battlegrounds    NaN   NaN  49,374,668  41,221,082   1,941,087
# 3   15 Key Battlegrounds    NaN   NaN         NaN         NaN         NaN
# 4                Arizona      D   Yes   1,672,143   1,661,686      53,497
# ..                   ...    ...   ...         ...         ...         ...
# 56               Vermont      D   Yes     242,820     112,704      11,904
# 57              Virginia      D   Yes   2,413,568   1,962,430      84,526
# 58            Washington      D   Yes   2,369,612   1,584,651     133,368
# 59         West Virginia      R   Yes     235,984     545,382      13,286
# 60               Wyoming      R   Yes      73,491     193,559       9,715
#
#    dem_percent rep_percent other_percent dem_this_margin  ... stateid    EV  \
# ...

# %%
# Dropping columns
vaccination_dfclean = title_df_renamed.drop(columns=["fips", "lat", "locationId", "long", "actuals.newCases", "actuals.vaccinesDistributed", "actuals.newDeaths",])
vaccination_dfclean
