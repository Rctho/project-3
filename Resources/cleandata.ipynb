# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
csv_file = "popular-vote-backend-Sheet1.csv"
popular_df = pd.read_csv(csv_file)

# %%
popular_df.head()
# Out:
#                   state called final   dem_votes   rep_votes other_votes  \
# 0            U.S. Total      D   Yes  81,282,916  74,223,369   2,891,441
# 1  15 Key Battlegrounds    NaN   NaN  31,908,248  33,002,287     950,354
# 2     Non-Battlegrounds    NaN   NaN  49,374,668  41,221,082   1,941,087
# 3  15 Key Battlegrounds    NaN   NaN         NaN         NaN         NaN
# 4               Arizona      D   Yes   1,672,143   1,661,686      53,497
#
#   dem_percent rep_percent other_percent dem_this_margin  ... stateid    EV  \
# 0       51.3%       46.9%          1.8%            4.5%  ...     NaN   NaN
# 1       48.4%       50.1%          1.4%           -1.7%  ...     NaN   NaN
# 2       53.4%       44.5%          2.1%            8.8%  ...     NaN   NaN
# 3         NaN         NaN           NaN             NaN  ...     NaN   NaN
# 4       49.4%       49.1%          1.6%            0.3%  ...      AZ  11.0
#
#      X    Y  State_num  Center_X  Center_Y  Unnamed: 19  2016 Margin  \
# ...

# %%
popular_df = popular_df[['state','dem_votes','rep_votes','dem_percent', 'rep_percent', 'stateid']]
popular_df.head(65)
popular_df
# Out:
#                    state   dem_votes   rep_votes dem_percent rep_percent  \
# 0             U.S. Total  81,282,916  74,223,369       51.3%       46.9%
# 1   15 Key Battlegrounds  31,908,248  33,002,287       48.4%       50.1%
# 2      Non-Battlegrounds  49,374,668  41,221,082       53.4%       44.5%
# 3   15 Key Battlegrounds         NaN         NaN         NaN         NaN
# 4                Arizona   1,672,143   1,661,686       49.4%       49.1%
# ..                   ...         ...         ...         ...         ...
# 56               Vermont     242,820     112,704       66.1%       30.7%
# 57              Virginia   2,413,568   1,962,430       54.1%       44.0%
# 58            Washington   2,369,612   1,584,651       58.0%       38.8%
# 59         West Virginia     235,984     545,382       29.7%       68.6%
# 60               Wyoming      73,491     193,559       26.6%       69.9%
#
#    stateid
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4       AZ
# ..     ...
# ...

# %%
popular_df.drop([0,1,2,3,8,11,19,36,43,44]).head(100)
# Out:
#                    state   dem_votes  rep_votes dem_percent rep_percent  \
# 4                Arizona   1,672,143  1,661,686       49.4%       49.1%
# 5                Florida   5,297,045  5,668,731       47.9%       51.2%
# 6                Georgia   2,473,633  2,461,854       49.5%       49.3%
# 7                   Iowa     759,061    897,672       44.9%       53.1%
# 9               Michigan   2,804,040  2,649,852       50.6%       47.8%
# 10             Minnesota   1,717,077  1,484,065       52.4%       45.3%
# 12                Nevada     703,486    669,890       50.1%       47.7%
# 13         New Hampshire     424,921    365,654       52.7%       45.4%
# 14        North Carolina   2,684,292  2,758,775       48.6%       49.9%
# 15                  Ohio   2,679,165  3,154,834       45.2%       53.3%
# 16          Pennsylvania   3,458,229  3,377,674       50.0%       48.8%
# 17                 Texas   5,259,126  5,890,347       46.5%       52.1%
# ...

# %%
popular_df.to_csv('cleaneddata.csv')
